# %% [markdown]
# This notebook can be used to run ShapeAE locally or in google colab
#
# We first install ShapeAE then set the paths and run it

# %%
# first we install ShapeAE using pip install 
# !pip3 install -i https://test.pypi.org/simple/ shapeae==0.0.21
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...

# %% [markdown]
# Now we choose the desired settings:
# settings.path : The path containing the image, mask and obj folder with correspondig files (see sample)
# settings.result_path : The path where ShapeAEs results should be saved
# settings.random_seed : The random seed
# settings.batch_size : The batchsize, we recommend an even number smaller than 10 and larger than 4
# settings.epochs_ShapeAE : The number of epochs ShapeAE should be trained in a supervised fashion
# settings.epochs_cShapeAE : The number of epochs ShapeAE should be trained with the discriminator

# %%
from shapeae import settings, run_train, run_evaluation
settings.path =  "/home/dominik/Documents/ShapeAE_SSL/docs/sample/"
settings.result_path =  "/home/dominik/Documents/ShapeAE_SSL/docs/sample/ShapeAE_results/"
#run ShapeAE
run_train()
# Out:
# Using TensorFlow backend.
# ------ settings parameters ------
# path: /home/dominik/Documents/ShapeAE_SSL/sample/
# result_path: /home/dominik/Documents/ShapeAE_SSL/sample/ShapeAE_results/
# pretrained_weights_path:
# random_seed: 0
# batch_size: 6
# epochs_ShapeAE: 30
# epochs_cShapeAE: 30
#
# For Validation we use: 22 randomly sampled files
# For training we use: 86 randomly sampled files
# 10 0.0
# Model: "Maskencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 1, None, None, 2) 0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 1, None, None, 10) 190
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1, None, None, 10) 40
# _________________________________________________________________
# ...
